# %%
import landsat as lsat
lsa=lsat.Landsat8()

# %%
# %matplotlib notebook
# %run l8_realtime_fly.py
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
lsa.get_nvisite()
# Out:
# [1, 17, 33, 49, 65, 81, 106, 122, 138, 154, 170, 186, 202, 218]

# %%
lsa.vtime(today_path,paths=True,zone='world')
# Out:
# <img src="data:image/png;base64,..." width="640">
